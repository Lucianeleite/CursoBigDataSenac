# %%
#Atividade 2 (Github)

#Replique os processos de leitura, cópia e consultas exercitados em aula utilizando um dataset livre pesquisado por você (dê preferencias a arquivos, .csv .xlsx, ou .json)

# %%
import pandas as pd
import numpy as np

# %%
#link arquivo .json -> https://www.ibge.gov.br/estatisticas/sociais/trabalho/9171-pesquisa-nacional-por-amostra-de-domicilios-continua-mensal.html

dados=pd.read_json('pesquisanacionalibge.json')
#display(dados)     
display(dados.head())  
estatistica=dados.describe()

display(dados.tail())  
display(dados)
display(estatistica) 

df_copia=dados.copy() 
display(df_copia)
# Out:
#                                                                                                source  \
# Taxa de desocupação, na semana de referência, d...  "IBGE - Pesquisa Nacional por Amostra de Domic...
# Variação em relação a três trimestres móveis an...  "IBGE - Pesquisa Nacional por Amostra de Domic...
# Variação em relação ao mesmo trimestre móvel do...  "IBGE - Pesquisa Nacional por Amostra de Domic...
#
#                                                                                                 title  \
# Taxa de desocupação, na semana de referência, d...  Taxa de desocupação das pessoas de 14 anos ou ...
# Variação em relação a três trimestres móveis an...  Taxa de desocupação das pessoas de 14 anos ou ...
# Variação em relação ao mesmo trimestre móvel do...  Taxa de desocupação das pessoas de 14 anos ou ...
#
#                                                              valuesMap
# Taxa de desocupação, na semana de referência, d...   {'Totals': '6,6'}
# ...
