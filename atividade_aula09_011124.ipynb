# %% [markdown]
# Atividade
#
# Atualize o resumo estatistico da aula anterior com as novas medidas de dispersão de hoje

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
amostra=[random.randint(100,200) for i in range(50)]
print(amostra)

amostra=np.sort(amostra)
print(amostra)
# Out:
# [131, 200, 146, 131, 101, 194, 188, 143, 156, 149, 162, 102, 190, 199, 147, 159, 155, 153, 126, 146, 195, 111, 176, 144, 162, 120, 136, 156, 142, 180, 183, 112, 128, 143, 199, 141, 199, 180, 104, 189, 165, 122, 108, 150, 134, 157, 107, 154, 147, 142]
# [101 102 104 107 108 111 112 120 122 126 128 131 131 134 136 141 142 142
#  143 143 144 146 146 147 147 149 150 153 154 155 156 156 157 159 162 162
#  165 176 180 180 183 188 189 190 194 195 199 199 199 200]

# %%
media=np.mean(amostra)
mediana=np.median(amostra)
distancia=(media-mediana)/mediana*100
q1=np.percentile(amostra,25) # o primeiro quartil representa 25% do total da amostra
q2=np.percentile(amostra,50) # mediana pode ser interpretada como o seu segundo quartil (quartil 50)
q3=np.percentile(amostra,75) # o terceiro quartil representa 75% do total da amostra

print(f'Média: {media}')
print(f'Mediana: {mediana}')
print (f'Distância entre média e mediana: {distancia:.2f}%')
print(f"Primeiro Quartil (Q1):{q1}")
print(f"Segundo Quartil (Q2):{q2}")
print(f"Terceiro Quartil (Q3):{q3}")
# Out:
# Média: 147.88
# Mediana: 142.0
# Distância entre média e mediana: 4.14%
# Primeiro Quartil (Q1):126.25
# Segundo Quartil (Q2):142.0
# Terceiro Quartil (Q3):174.5

# %%
amostra_df=pd.DataFrame(amostra, columns=['Valores'])
print(amostra_df)
# Out:
#     Valores
# 0       101
# 1       102
# 2       106
# 3       108
# 4       110
# 5       110
# 6       110
# 7       113
# 8       117
# 9       119
# 10      121
# 11      121
# 12      126
# 13      127
# 14      127
# 15      130
# 16      131
# 17      134
# 18      136
# 19      136
# 20      136
# 21      139
# 22      139
# 23      139
# 24      139
# 25      145
# 26      147
# 27      153
# 28      154
# 29      155
# 30      156
# 31      158
# 32      167
# 33      168
# 34      169
# 35      171
# 36      173
# 37      175
# 38      178
# 39      179
# 40      180
# 41      182
# 42      184
# 43      185
# 44      185
# 45      186
# 46      188
# 47      188
# 48      195
# 49      196

# %%
valor_maximo=amostra_df['Valores'].max()
valor_minimo=amostra_df['Valores'].min()
amplitude_total=valor_maximo-valor_minimo

print(f'Menor valor:{valor_minimo}')
print(f'Menor valor:{valor_minimo}')
print(f'Menor valor:{amplitude_total}')
# Out:
# Menor valor:101
# Menor valor:101
# Menor valor:95

# %%
fig,ax=plt.subplots(1,2,figsize=(12,6))

#Boxplot      [0] é linha    [1] é coluna
ax[0].boxplot(amostra_df['Valores'])
ax[0].set_title('Distribuição de Dados - Boxplot')
ax[0].set_ylabel('Valores')

#Exibindo as Medidas
ax[1].text(0.1,0.8, f"Menor Valor: {valor_minimo}")
ax[1].text(0.1,0.7, f"Maior Valor: {valor_maximo}")
ax[1].text(0.1,0.6, f"Amplitude Total: {amplitude_total}")
ax[1].set_axis_off()  #ocultar visualmente os eixos 

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
